# %%
#This is an example class that shows how Event_Visualizer can be used.
from event_visualizer import Event_Visualizer
import ROOT as r
# Out:
# Welcome to JupyROOT 6.24/00

# %%
EV = Event_Visualizer()

input_file = r.TFile("updated_remove_zeros.root")
tree_atar, tree_calo = EV.get_trees(input_file)

# %%
#Params: Should be only 1) File name, 2) Event index
max_Es, gap_times = EV.visualize_event(tree_atar, tree_calo, False, False, 314)
